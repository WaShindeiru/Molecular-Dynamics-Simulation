# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from various import read_atoms_from_output_dumps, get_distance
from pathlib import Path

# %% [markdown]
# ## c-c

# %%
path_c = Path("/mnt/7E442D59442D1585/md/paper/pot_energy/c-c")

temp_c = read_atoms_from_output_dumps(path_c / "laamps", 0, 1)

# %%
distance_c = get_distance(temp_c, 0, 1)

energy_data_c = pd.read_csv(path_c / "energy.csv", header=0)

# %%
# plt.figure()
# plt.plot(distance['iteration'], distance['distance'])
# plt.show()

plt.figure()
plt.plot(distance_c['distance'][1:], energy_data_c["potential_energy"][1:], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([-0.2, 4])
plt.ylim([-9, 20])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji C-C", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(fontsize=14)

plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/c-c/c-c-energy.png')
plt.show()

# %%
plt.figure()
plt.plot(distance_c['distance'][1:], energy_data_c["potential_energy"][1:], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([-0.2, 4])
plt.ylim([-20, 1100])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji C-C", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)


plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Asymptota')

plt.legend(fontsize=14)

plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/c-c/c-c-energy-big.png')

plt.show()

# %% [markdown]
# ## fe-fe

# %%
path_fe = Path("/mnt/7E442D59442D1585/md/paper/pot_energy/fe-fe")

temp_fe = read_atoms_from_output_dumps(path_fe / "laamps", 0, 1)

# %%
distance_fe = get_distance(temp_fe, 0, 1)

energy_data_fe = pd.read_csv(path_fe / "energy.csv", header=0)

# %%
plt.figure()
plt.plot(distance_fe['distance'][1:], energy_data_fe["potential_energy"][1:], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([0, 4])
plt.ylim([-9, 20])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji Fe-Fe", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(fontsize=14)
plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/fe-fe/fe-fe-energy.png')
plt.show()

# %%
plt.figure()
plt.plot(distance_fe['distance'][1:], energy_data_fe["potential_energy"][1:], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([-0.2, 4])
plt.ylim([-20, 820])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji Fe-Fe", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)


plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Asymptota')

plt.legend(fontsize=14)

plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/fe-fe/fe-fe-energy-big.png')

plt.show()

# %% [markdown]
# ## fe-c

# %%
path_fec = Path("/mnt/7E442D59442D1585/md/paper/pot_energy/fe-c")

temp_fec = read_atoms_from_output_dumps(path_fec / "laamps", 0, 1)

# %%
distance_fec = get_distance(temp_fec, 0, 1)

energy_data_fec = pd.read_csv(path_fec / "energy.csv", header=0)

# %%
plt.figure()
plt.plot(distance_fec['distance'], energy_data_fec["potential_energy"], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([0, 4])
plt.ylim([-9, 20])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji Fe-C", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(fontsize=14)
plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/fe-c/fe-c-energy.png')
plt.show()

# %%
plt.figure()
plt.plot(distance_fe['distance'][1:], energy_data_fe["potential_energy"][1:], color='darkcyan', linewidth=3, label="Energia potencjalna")
plt.xlim([-0.2, 4])
plt.ylim([-20, 850])
plt.xlabel("Odległość [A]", fontsize=15)
plt.ylabel("Energia potencjalna [eV]", fontsize=15)
plt.title("Zależność energii potencjalnej od odległości\n dla interakcji Fe-C", pad=5, fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)


plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Asymptota')

plt.legend(fontsize=14)

plt.savefig('/mnt/7E442D59442D1585/md/paper/pot_energy/fe-c/fe-c-energy-big.png')

plt.show()
